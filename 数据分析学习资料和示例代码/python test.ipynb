# %% [markdown]
# ## this is a title

# %%
1+231
# Out:
# 232

# %%
3+4
# Out:
# 7

# %%
import math

# %%
math.sqrt(10)
# Out:
# 3.1622776601683795

# %%
import random

# %%
import numpy as np

# %%
import numpy as np

# %%
np.random.randn(10)
# Out:
# array([ 0.91206341, -1.09949255, -1.56594359, -1.16591052, -2.11196384,
#        -1.73709169,  0.71378879, -1.60211235,  0.84585094, -1.59100441])

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt, numpy as np

# %%
x = np.arrange(20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-8b982d5c65be> in <module>
# ----> 1 x = np.arrange(20)
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %%
x = np.arange(20)

# %%
y = x**2

# %%
plt.plot(x,y)

# %%
import numpy as np                                                               
import matplotlib.pyplot as plt                                                                                                                                 

x = np.linspace(0, 1,100)
fig = plt.figure()                                                               
ax = fig.add_subplot(1,1,1)
ax.set_title("shiyanlou")

ax.plot(x, x ** (1/8), 'b--', label=r'$y = x^{1/8}$')
ax.plot(x, x ** 8, 'r--', label=r'$y = x^{8}$')

ax.plot(x, x ** (1/2), 'r.', label=r'$y = x^{1/2}$')
ax.plot(x, x ** 2, 'b.', label=r'$y = x^{2}$')

ax.plot(x, x, 'g-', label=r'$y = x$')

#ax.legend()
ax.axis([0, 1, 0, 1])
# Out:
# [0, 1, 0, 1]
